# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + cities[i] + "&units=imperial" + "&appid=" + weather_api_key
    #city_url = url + "&q=" + city.replace(" ","+") + "&units=imperial" + weather_api_key
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Description":city_description})      
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | ambilobe
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | lazaro cardenas
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | bonavista
# Processing Record 14 of Set 1 | fuerte olimpo
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | lavrentiya
# Processing Record 17 of Set 1 | sinnamary
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | valle de allende
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | aklavik
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | kaka
# Processing Record 29 of Set 1 | zatoka
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | westport
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | carballo
# Processing Record 35 of Set 1 | linares
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | roald
# Processing Record 39 of Set 1 | axim
# Processing Record 40 of Set 1 | palafrugell
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | lasa
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | pemba
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | hami
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | dogondoutchi
# Processing Record 4 of Set 2 | nichinan
# Processing Record 5 of Set 2 | trelew
# Processing Record 6 of Set 2 | mehamn
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | tezu
# Processing Record 12 of Set 2 | matola
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 2 | ust-tarka
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | nuevitas
# Processing Record 21 of Set 2 | abu samrah
# Processing Record 22 of Set 2 | russell
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | dunedin
# Processing Record 25 of Set 2 | rasulabad
# Processing Record 26 of Set 2 | saint-joseph
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | sur
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | ranong
# Processing Record 33 of Set 2 | bohicon
# Processing Record 34 of Set 2 | yatou
# Processing Record 35 of Set 2 | a
# City not found. Skipping...
# Processing Record 36 of Set 2 | tuatapere
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | elmira
# Processing Record 41 of Set 2 | te anau
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | olafsvik
# Processing Record 46 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint marys
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | lincoln
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | yurty
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | waw
# Processing Record 4 of Set 3 | burica
# City not found. Skipping...
# Processing Record 5 of Set 3 | dasoguz
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 3 | raudeberg
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | denpasar
# Processing Record 13 of Set 3 | coahuayana
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | inuvik
# Processing Record 17 of Set 3 | owando
# Processing Record 18 of Set 3 | marang
# Processing Record 19 of Set 3 | klang
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | nakamura
# Processing Record 23 of Set 3 | turan
# Processing Record 24 of Set 3 | mao
# Processing Record 25 of Set 3 | yumen
# Processing Record 26 of Set 3 | sao pedro do sul
# Processing Record 27 of Set 3 | dire
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 3 | qarchi gak
# Processing Record 31 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | pitimbu
# Processing Record 35 of Set 3 | brigantine
# Processing Record 36 of Set 3 | annau
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | stornoway
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | nyurba
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | olinda
# Processing Record 47 of Set 3 | north bend
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | san juan
# Processing Record 50 of Set 3 | hargeysa
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | qasigiannguit
# Processing Record 3 of Set 4 | nouadhibou
# Processing Record 4 of Set 4 | bontang
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | nishihara
# Processing Record 7 of Set 4 | shihezi
# Processing Record 8 of Set 4 | ostrovnoy
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | lugoba
# Processing Record 12 of Set 4 | manaure
# Processing Record 13 of Set 4 | beloha
# Processing Record 14 of Set 4 | srednekolymsk
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 4 | jinchang
# Processing Record 19 of Set 4 | port moresby
# Processing Record 20 of Set 4 | chabahar
# Processing Record 21 of Set 4 | waingapu
# Processing Record 22 of Set 4 | copiapo
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | khandyga
# Processing Record 25 of Set 4 | mayumba
# Processing Record 26 of Set 4 | goderich
# Processing Record 27 of Set 4 | tilichiki
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | rantoul
# Processing Record 30 of Set 4 | gat
# Processing Record 31 of Set 4 | pemangkat
# Processing Record 32 of Set 4 | dicabisagan
# Processing Record 33 of Set 4 | shibetsu
# Processing Record 34 of Set 4 | moose factory
# Processing Record 35 of Set 4 | buckeye
# Processing Record 36 of Set 4 | alpine
# Processing Record 37 of Set 4 | kuytun
# Processing Record 38 of Set 4 | savannah bight
# Processing Record 39 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa fe
# Processing Record 42 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 4 | college
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | carutapera
# Processing Record 48 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 49 of Set 4 | hibbing
# Processing Record 50 of Set 4 | kungurtug
# Processing Record 1 of Set 5 | muravlenko
# Processing Record 2 of Set 5 | umm kaddadah
# Processing Record 3 of Set 5 | asau
# Processing Record 4 of Set 5 | verkhnevilyuysk
# Processing Record 5 of Set 5 | honiara
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | oyem
# Processing Record 8 of Set 5 | luderitz
# Processing Record 9 of Set 5 | kununurra
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | alice springs
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | krivodol
# Processing Record 14 of Set 5 | neryungri
# Processing Record 15 of Set 5 | poso
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | lipari
# Processing Record 18 of Set 5 | karlskoga
# Processing Record 19 of Set 5 | catamarca
# Processing Record 20 of Set 5 | bam
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | mahajanga
# Processing Record 23 of Set 5 | sampit
# Processing Record 24 of Set 5 | teguldet
# Processing Record 25 of Set 5 | bluff
# Processing Record 26 of Set 5 | cap-aux-meules
# Processing Record 27 of Set 5 | vila franca do campo
# Processing Record 28 of Set 5 | perama
# Processing Record 29 of Set 5 | esperance
# Processing Record 30 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 5 | riosucio
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 5 | birjand
# Processing Record 34 of Set 5 | sechura
# Processing Record 35 of Set 5 | hobyo
# Processing Record 36 of Set 5 | kadirli
# Processing Record 37 of Set 5 | baglung
# Processing Record 38 of Set 5 | esil
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | whyalla
# Processing Record 41 of Set 5 | pedernales
# Processing Record 42 of Set 5 | dalbandin
# Processing Record 43 of Set 5 | seminole
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | channel-port aux basques
# Processing Record 46 of Set 5 | litija
# Processing Record 47 of Set 5 | vaitape
# Processing Record 48 of Set 5 | mbanza-ngungu
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | mandurah
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | orsha
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | peniche
# Processing Record 7 of Set 6 | preobrazheniye
# Processing Record 8 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 6 | berezovyy
# Processing Record 10 of Set 6 | pevek
# Processing Record 11 of Set 6 | belaya gora
# Processing Record 12 of Set 6 | lebork
# Processing Record 13 of Set 6 | kihei
# Processing Record 14 of Set 6 | ajaccio
# Processing Record 15 of Set 6 | skala
# Processing Record 16 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 6 | tura
# Processing Record 18 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 6 | nouakchott
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | lima
# Processing Record 23 of Set 6 | saint-augustin
# Processing Record 24 of Set 6 | macas
# Processing Record 25 of Set 6 | baie-comeau
# Processing Record 26 of Set 6 | sept-iles
# Processing Record 27 of Set 6 | letlhakeng
# Processing Record 28 of Set 6 | coquimbo
# Processing Record 29 of Set 6 | nefteyugansk
# Processing Record 30 of Set 6 | teya
# Processing Record 31 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 6 | keti bandar
# Processing Record 33 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 6 | naryan-mar
# Processing Record 35 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 6 | esso
# Processing Record 37 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 6 | terrace
# Processing Record 39 of Set 6 | northam
# Processing Record 40 of Set 6 | taoudenni
# Processing Record 41 of Set 6 | rocha
# Processing Record 42 of Set 6 | razole
# Processing Record 43 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | veraval
# Processing Record 45 of Set 6 | camacha
# Processing Record 46 of Set 6 | iqaluit
# Processing Record 47 of Set 6 | atar
# Processing Record 48 of Set 6 | karratha
# Processing Record 49 of Set 6 | saravena
# Processing Record 50 of Set 6 | havelock
# Processing Record 1 of Set 7 | jumla
# Processing Record 2 of Set 7 | sorgun
# Processing Record 3 of Set 7 | piacabucu
# Processing Record 4 of Set 7 | torbat-e jam
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 7 | vanimo
# Processing Record 8 of Set 7 | shaunavon
# Processing Record 9 of Set 7 | castro
# Processing Record 10 of Set 7 | natchez
# Processing Record 11 of Set 7 | khani
# Processing Record 12 of Set 7 | sehithwa
# Processing Record 13 of Set 7 | tripoli
# Processing Record 14 of Set 7 | bud
# Processing Record 15 of Set 7 | ponta pora
# Processing Record 16 of Set 7 | colesberg
# Processing Record 17 of Set 7 | inirida
# Processing Record 18 of Set 7 | tarata
# Processing Record 19 of Set 7 | nyrob
# Processing Record 20 of Set 7 | rudnya
# Processing Record 21 of Set 7 | cervo
# Processing Record 22 of Set 7 | mundo nuevo
# Processing Record 23 of Set 7 | gasa
# Processing Record 24 of Set 7 | laguna
# Processing Record 25 of Set 7 | nelson bay
# Processing Record 26 of Set 7 | mbekenyera
# Processing Record 27 of Set 7 | komsomolskiy
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | nabire
# Processing Record 31 of Set 7 | chimbote
# Processing Record 32 of Set 7 | gushikawa
# Processing Record 33 of Set 7 | mayo
# Processing Record 34 of Set 7 | fort nelson
# Processing Record 35 of Set 7 | cabedelo
# Processing Record 36 of Set 7 | sertaozinho
# Processing Record 37 of Set 7 | san quintin
# Processing Record 38 of Set 7 | haines junction
# Processing Record 39 of Set 7 | samarai
# Processing Record 40 of Set 7 | kodinar
# Processing Record 41 of Set 7 | sinop
# Processing Record 42 of Set 7 | muros
# Processing Record 43 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 7 | vasilkovo
# City not found. Skipping...
# Processing Record 45 of Set 7 | moerai
# Processing Record 46 of Set 7 | san policarpo
# Processing Record 47 of Set 7 | tual
# Processing Record 48 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | ugoofaaru
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 8 | araouane
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | oistins
# Processing Record 6 of Set 8 | maurawan
# Processing Record 7 of Set 8 | koshurnikovo
# Processing Record 8 of Set 8 | necochea
# Processing Record 9 of Set 8 | ericeira
# Processing Record 10 of Set 8 | cay
# Processing Record 11 of Set 8 | nikel
# Processing Record 12 of Set 8 | mkushi
# Processing Record 13 of Set 8 | arlit
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | jalu
# Processing Record 16 of Set 8 | japura
# Processing Record 17 of Set 8 | mega
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | aykhal
# Processing Record 20 of Set 8 | novyy urengoy
# Processing Record 21 of Set 8 | allapalli
# Processing Record 22 of Set 8 | hambantota
# Processing Record 23 of Set 8 | faanui
# Processing Record 24 of Set 8 | vitim
# Processing Record 25 of Set 8 | cookeville
# Processing Record 26 of Set 8 | coruripe
# Processing Record 27 of Set 8 | tomatlan
# Processing Record 28 of Set 8 | valdivia
# Processing Record 29 of Set 8 | san francisco
# Processing Record 30 of Set 8 | mitsamiouli
# Processing Record 31 of Set 8 | ilebo
# Processing Record 32 of Set 8 | baghdad
# Processing Record 33 of Set 8 | kawalu
# Processing Record 34 of Set 8 | santa vitoria do palmar
# Processing Record 35 of Set 8 | balkhash
# Processing Record 36 of Set 8 | shelbyville
# Processing Record 37 of Set 8 | kidal
# Processing Record 38 of Set 8 | najran
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | basyanovskiy
# City not found. Skipping...
# Processing Record 41 of Set 8 | bilibino
# Processing Record 42 of Set 8 | edremit
# Processing Record 43 of Set 8 | biak
# Processing Record 44 of Set 8 | sioux lookout
# Processing Record 45 of Set 8 | tolaga bay
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | byron bay
# Processing Record 48 of Set 8 | karibib
# Processing Record 49 of Set 8 | hofn
# Processing Record 50 of Set 8 | santa isabel
# Processing Record 1 of Set 9 | salalah
# Processing Record 2 of Set 9 | bathsheba
# Processing Record 3 of Set 9 | richards bay
# Processing Record 4 of Set 9 | nicoya
# Processing Record 5 of Set 9 | lucea
# Processing Record 6 of Set 9 | ballina
# Processing Record 7 of Set 9 | cidreira
# Processing Record 8 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 9 | agaro
# Processing Record 10 of Set 9 | thunder bay
# Processing Record 11 of Set 9 | praia da vitoria
# Processing Record 12 of Set 9 | nador
# Processing Record 13 of Set 9 | banjar
# Processing Record 14 of Set 9 | gogrial
# Processing Record 15 of Set 9 | acapulco
# Processing Record 16 of Set 9 | oranjemund
# Processing Record 17 of Set 9 | beitbridge
# Processing Record 18 of Set 9 | salekhard
# Processing Record 19 of Set 9 | turukhansk
# Processing Record 20 of Set 9 | opuwo
# Processing Record 21 of Set 9 | jutai
# Processing Record 22 of Set 9 | rabo de peixe
# Processing Record 23 of Set 9 | diego de almagro
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | nanakuli
# Processing Record 27 of Set 9 | uchiza
# Processing Record 28 of Set 9 | kouango
# Processing Record 29 of Set 9 | souillac
# Processing Record 30 of Set 9 | rincon
# Processing Record 31 of Set 9 | maltahohe
# Processing Record 32 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 9 | riyadh
# Processing Record 34 of Set 9 | san juan bautista
# Processing Record 35 of Set 9 | avera
# Processing Record 36 of Set 9 | kjollefjord
# Processing Record 37 of Set 9 | capreol
# Processing Record 38 of Set 9 | srandakan
# Processing Record 39 of Set 9 | tiznit
# Processing Record 40 of Set 9 | laurel
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | ibiruba
# Processing Record 43 of Set 9 | glenwood springs
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | kamina
# Processing Record 46 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 9 | santander
# Processing Record 48 of Set 9 | kamaishi
# Processing Record 49 of Set 9 | bubaque
# Processing Record 50 of Set 9 | vryburg
# Processing Record 1 of Set 10 | bitkine
# Processing Record 2 of Set 10 | san patricio
# Processing Record 3 of Set 10 | nieuw amsterdam
# Processing Record 4 of Set 10 | taunggyi
# Processing Record 5 of Set 10 | cayenne
# Processing Record 6 of Set 10 | sembe
# Processing Record 7 of Set 10 | geraldton
# Processing Record 8 of Set 10 | chunhuhub
# Processing Record 9 of Set 10 | vanavara
# Processing Record 10 of Set 10 | road town
# Processing Record 11 of Set 10 | pangnirtung
# Processing Record 12 of Set 10 | morbegno
# Processing Record 13 of Set 10 | acarau
# Processing Record 14 of Set 10 | saint-georges
# Processing Record 15 of Set 10 | ossora
# Processing Record 16 of Set 10 | skjervoy
# Processing Record 17 of Set 10 | alexandria
# Processing Record 18 of Set 10 | petauke
# Processing Record 19 of Set 10 | cheremisinovo
# Processing Record 20 of Set 10 | brae
# Processing Record 21 of Set 10 | solnechnyy
# Processing Record 22 of Set 10 | fortuna
# Processing Record 23 of Set 10 | byumba
# Processing Record 24 of Set 10 | ribeira brava
# Processing Record 25 of Set 10 | tananger
# Processing Record 26 of Set 10 | oxford
# Processing Record 27 of Set 10 | thinadhoo
# Processing Record 28 of Set 10 | rakaia
# Processing Record 29 of Set 10 | immokalee
# Processing Record 30 of Set 10 | carrollton
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | kautokeino
# Processing Record 33 of Set 10 | madimba
# Processing Record 34 of Set 10 | ulladulla
# Processing Record 35 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 10 | malazgirt
# Processing Record 37 of Set 10 | kirchlinteln
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | hinton
# Processing Record 40 of Set 10 | pingxiang
# Processing Record 41 of Set 10 | nuuk
# Processing Record 42 of Set 10 | vichayal
# City not found. Skipping...
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 10 | lukiv
# Processing Record 46 of Set 10 | wamba
# Processing Record 47 of Set 10 | saint-francois
# Processing Record 48 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 10 | bethel
# Processing Record 50 of Set 10 | duz
# City not found. Skipping...
# Processing Record 1 of Set 11 | dargaville
# Processing Record 2 of Set 11 | seymchan
# Processing Record 3 of Set 11 | wadi musa
# Processing Record 4 of Set 11 | storslett
# Processing Record 5 of Set 11 | micheweni
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | bukan
# Processing Record 8 of Set 11 | sorland
# Processing Record 9 of Set 11 | izhmorskiy
# Processing Record 10 of Set 11 | udachnyy
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | calabozo
# Processing Record 13 of Set 11 | vitry-le-francois
# Processing Record 14 of Set 11 | high rock
# Processing Record 15 of Set 11 | nueva gerona
# Processing Record 16 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 11 | letterkenny
# Processing Record 18 of Set 11 | garowe
# Processing Record 19 of Set 11 | merrill
# Processing Record 20 of Set 11 | dolinsk
# Processing Record 21 of Set 11 | weert
# Processing Record 22 of Set 11 | kelvington
# Processing Record 23 of Set 11 | ongandjera
# Processing Record 24 of Set 11 | pervomayskiy
# Processing Record 25 of Set 11 | wanxian
# Processing Record 26 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 11 | tumkur
# Processing Record 28 of Set 11 | tutoia
# Processing Record 29 of Set 11 | flin flon
# Processing Record 30 of Set 11 | masuguru
# Processing Record 31 of Set 11 | oranjestad
# Processing Record 32 of Set 11 | raahe
# Processing Record 33 of Set 11 | vieques
# Processing Record 34 of Set 11 | barcelos
# Processing Record 35 of Set 11 | kologriv
# Processing Record 36 of Set 11 | minab
# Processing Record 37 of Set 11 | ocos
# Processing Record 38 of Set 11 | karema
# Processing Record 39 of Set 11 | hay river
# Processing Record 40 of Set 11 | saint-pierre
# Processing Record 41 of Set 11 | ferme-neuve
# Processing Record 42 of Set 11 | excelsior springs
# Processing Record 43 of Set 11 | gornyy
# Processing Record 44 of Set 11 | trinidad
# Processing Record 45 of Set 11 | boyolangu
# Processing Record 46 of Set 11 | derac
# Processing Record 47 of Set 11 | elizabeth city
# Processing Record 48 of Set 11 | atasu
# Processing Record 49 of Set 11 | soe
# Processing Record 50 of Set 11 | puri
# Processing Record 1 of Set 12 | surt
# Processing Record 2 of Set 12 | el calvario
# Processing Record 3 of Set 12 | ust-koksa
# Processing Record 4 of Set 12 | chara
# Processing Record 5 of Set 12 | tucupita
# Processing Record 6 of Set 12 | lethem
# Processing Record 7 of Set 12 | korogwe
# City not found. Skipping...
# Processing Record 8 of Set 12 | bratsk
# Processing Record 9 of Set 12 | mabai
# Processing Record 10 of Set 12 | sistranda
# Processing Record 11 of Set 12 | kaputa
# Processing Record 12 of Set 12 | takoradi
# Processing Record 13 of Set 12 | daru
# Processing Record 14 of Set 12 | siloam springs
# Processing Record 15 of Set 12 | tarauaca
# Processing Record 16 of Set 12 | port hardy
# Processing Record 17 of Set 12 | fengrun
# Processing Record 18 of Set 12 | klishkivtsi
# Processing Record 19 of Set 12 | matam
# Processing Record 20 of Set 12 | shakawe
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | taketa
# Processing Record 23 of Set 12 | nalut
# Processing Record 24 of Set 12 | westerland
# Processing Record 25 of Set 12 | dingle
# Processing Record 26 of Set 12 | orshanka
# Processing Record 27 of Set 12 | aasiaat
# Processing Record 28 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 12 | dudinka
# Processing Record 30 of Set 12 | bairiki
# Processing Record 31 of Set 12 | tabas
# Processing Record 32 of Set 12 | savalou
# Processing Record 33 of Set 12 | ust-kuyga
# Processing Record 34 of Set 12 | talara
# Processing Record 35 of Set 12 | auki
# Processing Record 36 of Set 12 | kulhudhuffushi
# Processing Record 37 of Set 12 | ciudad bolivar
# Processing Record 38 of Set 12 | berlevag
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | ewa beach
# Processing Record 41 of Set 12 | port augusta
# Processing Record 42 of Set 12 | chemal
# Processing Record 43 of Set 12 | batagay-alyta
# Processing Record 44 of Set 12 | orlik
# Processing Record 45 of Set 12 | skibbereen
# Processing Record 46 of Set 12 | gravdal
# Processing Record 47 of Set 12 | astoria
# Processing Record 48 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 12 | salta
# Processing Record 50 of Set 12 | quatre cocos
# Processing Record 1 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 13 | pietersburg
# Processing Record 3 of Set 13 | wakkanai
# Processing Record 4 of Set 13 | moindou
# Processing Record 5 of Set 13 | okhotsk
# Processing Record 6 of Set 13 | namibe
# Processing Record 7 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 13 | dawson creek
# Processing Record 9 of Set 13 | beyneu
# Processing Record 10 of Set 13 | sadovoye
# Processing Record 11 of Set 13 | kolaras
# Processing Record 12 of Set 13 | wanning
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | swan hill
# Processing Record 15 of Set 13 | batsfjord
# Processing Record 16 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 13 | ixtapa
# Processing Record 18 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 13 | qiongshan
# Processing Record 20 of Set 13 | da lat
# Processing Record 21 of Set 13 | blatnica
# Processing Record 22 of Set 13 | suyapa de lean
# City not found. Skipping...
# Processing Record 23 of Set 13 | smithers
# Processing Record 24 of Set 13 | weiser
# Processing Record 25 of Set 13 | mayya
# Processing Record 26 of Set 13 | santo amaro da imperatriz
# Processing Record 27 of Set 13 | margate
# Processing Record 28 of Set 13 | krasnyy chikoy
# Processing Record 29 of Set 13 | cairns
# Processing Record 30 of Set 13 | pakxan
# Processing Record 31 of Set 13 | egvekinot
# Processing Record 32 of Set 13 | banepa
# Processing Record 33 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 13 | gemena
# Processing Record 35 of Set 13 | slave lake
# Processing Record 36 of Set 13 | narsaq
# Processing Record 37 of Set 13 | vila
# Processing Record 38 of Set 13 | abu dhabi
# Processing Record 39 of Set 13 | athabasca
# Processing Record 40 of Set 13 | boa vista
# Processing Record 41 of Set 13 | gorin
# Processing Record 42 of Set 13 | cherdyn
# Processing Record 43 of Set 13 | simi
# Processing Record 44 of Set 13 | harper
# Processing Record 45 of Set 13 | la ligua
# Processing Record 46 of Set 13 | grand gaube
# Processing Record 47 of Set 13 | evensk
# Processing Record 48 of Set 13 | puerto colombia
# Processing Record 49 of Set 13 | lamu
# Processing Record 50 of Set 13 | maragogi
# Processing Record 1 of Set 14 | ahmadpur east
# Processing Record 2 of Set 14 | voznesenskoye
# Processing Record 3 of Set 14 | girne
# Processing Record 4 of Set 14 | belyy yar
# Processing Record 5 of Set 14 | edd
# Processing Record 6 of Set 14 | palmer
# Processing Record 7 of Set 14 | nanortalik
# Processing Record 8 of Set 14 | kasama
# Processing Record 9 of Set 14 | penzance
# Processing Record 10 of Set 14 | koslan
# Processing Record 11 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 14 | aktash
# Processing Record 13 of Set 14 | todos santos
# Processing Record 14 of Set 14 | suhbaatar
# Processing Record 15 of Set 14 | yar-sale
# Processing Record 16 of Set 14 | sao jose da coroa grande
# Processing Record 17 of Set 14 | waldoboro
# Processing Record 18 of Set 14 | poum
# Processing Record 19 of Set 14 | vadso
# Processing Record 20 of Set 14 | muscat
# Processing Record 21 of Set 14 | orel-izumrud
# Processing Record 22 of Set 14 | enshi
# Processing Record 23 of Set 14 | abbeville
# Processing Record 24 of Set 14 | swellendam
# Processing Record 25 of Set 14 | eyl
# Processing Record 26 of Set 14 | mnogovershinnyy
# Processing Record 27 of Set 14 | buraydah
# Processing Record 28 of Set 14 | nhulunbuy
# Processing Record 29 of Set 14 | mukhen
# Processing Record 30 of Set 14 | ejido
# Processing Record 31 of Set 14 | gao
# Processing Record 32 of Set 14 | vila do maio
# Processing Record 33 of Set 14 | kudymkar
# Processing Record 34 of Set 14 | mulege
# Processing Record 35 of Set 14 | praya
# Processing Record 36 of Set 14 | kysyl-syr
# Processing Record 37 of Set 14 | kutum
# Processing Record 38 of Set 14 | nikki
# Processing Record 39 of Set 14 | neuquen
# Processing Record 40 of Set 14 | birmingham
# Processing Record 41 of Set 14 | zheleznodorozhnyy
# Processing Record 42 of Set 14 | charters towers
# Processing Record 43 of Set 14 | meadow lake
# Processing Record 44 of Set 14 | christchurch
# Processing Record 45 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 14 | roebourne
# Processing Record 47 of Set 14 | maracacume
# Processing Record 48 of Set 14 | brenham
# Processing Record 49 of Set 14 | teknaf
# Processing Record 50 of Set 14 | ust-maya
# Processing Record 1 of Set 15 | manokwari
# Processing Record 2 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 3 of Set 15 | grants pass
# Processing Record 4 of Set 15 | juba
# Processing Record 5 of Set 15 | halifax
# Processing Record 6 of Set 15 | japoata
# Processing Record 7 of Set 15 | karachi
# Processing Record 8 of Set 15 | chebsara
# Processing Record 9 of Set 15 | englewood
# Processing Record 10 of Set 15 | tatawin
# Processing Record 11 of Set 15 | luba
# Processing Record 12 of Set 15 | collie
# Processing Record 13 of Set 15 | jambalo
# Processing Record 14 of Set 15 | porto velho
# Processing Record 15 of Set 15 | awbari
# Processing Record 16 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 15 | valentin gomez farias
# Processing Record 18 of Set 15 | lujan
# Processing Record 19 of Set 15 | lisakovsk
# Processing Record 20 of Set 15 | bilma
# Processing Record 21 of Set 15 | balkanabat
# Processing Record 22 of Set 15 | magistralnyy
# Processing Record 23 of Set 15 | gawler
# Processing Record 24 of Set 15 | fiumicino
# Processing Record 25 of Set 15 | de aar
# Processing Record 26 of Set 15 | banfora
# Processing Record 27 of Set 15 | znamenskoye
# Processing Record 28 of Set 15 | marshfield
# Processing Record 29 of Set 15 | bara
# Processing Record 30 of Set 15 | hirara
# Processing Record 31 of Set 15 | karasjok
# Processing Record 32 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 15 | vasilyevo
# Processing Record 34 of Set 15 | padang
# Processing Record 35 of Set 15 | aden
# Processing Record 36 of Set 15 | sotouboua
# Processing Record 37 of Set 15 | zhigalovo
# Processing Record 38 of Set 15 | makakilo city
# Processing Record 39 of Set 15 | umm lajj
# Processing Record 40 of Set 15 | portland
# Processing Record 41 of Set 15 | kattivakkam
# Processing Record 42 of Set 15 | haikou
# Processing Record 43 of Set 15 | rio grande
# Processing Record 44 of Set 15 | rehli
# Processing Record 45 of Set 15 | methoni
# Processing Record 46 of Set 15 | nizhniy kuranakh
# Processing Record 47 of Set 15 | tahe
# Processing Record 48 of Set 15 | kharp
# Processing Record 49 of Set 15 | dwarka
# Processing Record 50 of Set 15 | guantanamo
# Processing Record 1 of Set 16 | nkayi
# Processing Record 2 of Set 16 | ghansor
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife  62.4560 -114.3525     33.57        80          22
# 1     Norman Wells  65.2820 -126.8329     29.03        93         100
# 2    Mar Del Plata -38.0023  -57.5575     56.08        90           0
# 3          Mataura -46.1927  168.8643     56.48        44         100
# 4            Sitka  57.0531 -135.3300     57.09        82         100
# 5        Cape Town -33.9258   18.4232     63.12        92          75
# 6         Ambilobe -13.2000   49.0500     68.72        78          52
# 7           Dikson  73.5069   80.5464     28.76        94         100
# 8  Lazaro Cardenas  17.9583 -102.2000     81.36        80          86
# 9      Port Alfred -33.5906   26.8910     62.19        96         100
#
#    Wind Speed Country                 Date      Description
# 0       15.01      CA  2022-10-17 02:07:14       few clouds
# 1        5.06      CA  2022-10-17 02:10:30  overcast clouds
# 2       10.00      AR  2022-10-17 02:08:55        clear sky
# 3        4.61      NZ  2022-10-17 02:10:30  overcast clouds
# 4        9.22      US  2022-10-17 02:10:31  overcast clouds
# 5       14.97      ZA  2022-10-17 02:05:42    broken clouds
# 6        4.83      MG  2022-10-17 02:08:38    broken clouds
# 7        9.84      RU  2022-10-17 02:10:32  overcast clouds
# 8        3.87      MX  2022-10-17 02:10:33  overcast clouds
# 9       11.61      ZA  2022-10-17 02:10:33  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp",
                  "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife      CA  62.4560 -114.3525     33.57        80          22
# 1     Norman Wells      CA  65.2820 -126.8329     29.03        93         100
# 2    Mar Del Plata      AR -38.0023  -57.5575     56.08        90           0
# 3          Mataura      NZ -46.1927  168.8643     56.48        44         100
# 4            Sitka      US  57.0531 -135.3300     57.09        82         100
# 5        Cape Town      ZA -33.9258   18.4232     63.12        92          75
# 6         Ambilobe      MG -13.2000   49.0500     68.72        78          52
# 7           Dikson      RU  73.5069   80.5464     28.76        94         100
# 8  Lazaro Cardenas      MX  17.9583 -102.2000     81.36        80          86
# 9      Port Alfred      ZA -33.5906   26.8910     62.19        96         100
#
#    Wind Speed      Description
# 0       15.01       few clouds
# 1        5.06  overcast clouds
# 2       10.00        clear sky
# 3        4.61  overcast clouds
# 4        9.22  overcast clouds
# 5       14.97    broken clouds
# 6        4.83    broken clouds
# 7        9.84  overcast clouds
# 8        3.87  overcast clouds
# 9       11.61  overcast clouds

# %%
city_data_df.columns = city_data_df.columns.str.replace('Description', 'Current Description')
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife      CA  62.4560 -114.3525     33.57        80          22
# 1     Norman Wells      CA  65.2820 -126.8329     29.03        93         100
# 2    Mar Del Plata      AR -38.0023  -57.5575     56.08        90           0
# 3          Mataura      NZ -46.1927  168.8643     56.48        44         100
# 4            Sitka      US  57.0531 -135.3300     57.09        82         100
# 5        Cape Town      ZA -33.9258   18.4232     63.12        92          75
# 6         Ambilobe      MG -13.2000   49.0500     68.72        78          52
# 7           Dikson      RU  73.5069   80.5464     28.76        94         100
# 8  Lazaro Cardenas      MX  17.9583 -102.2000     81.36        80          86
# 9      Port Alfred      ZA -33.5906   26.8910     62.19        96         100
#
#    Wind Speed Current Description
# 0       15.01          few clouds
# 1        5.06     overcast clouds
# 2       10.00           clear sky
# 3        4.61     overcast clouds
# 4        9.22     overcast clouds
# 5       14.97       broken clouds
# 6        4.83       broken clouds
# 7        9.84     overcast clouds
# 8        3.87     overcast clouds
# 9       11.61     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
